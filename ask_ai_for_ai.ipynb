# %%
import requests
import json


def call_llm(input):
    url = "https://api.x.ai/v1/chat/completions"
    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer xai-coNazxZM4o2o5tLaKOBgHIsTFEREhCrKAIevsTdfKQdvAHPYPRFieecYuVfbqLNDROXiUO6X6STyGww4"
    }


    data = {
        "messages": [
            {
                "role": "system",
                "content": "You are a test assistant."
            },
            {
                "role": "user",
                "content": input
            }
        ],
        "model": "grok-4-latest",
        "stream": False,
        "temperature": 0
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))

    # 打印返回的 JSON
    # print(response.json()['choices'][0]['message']['content'])
    return response.json()['choices'][0]['message']['content']

# %%
import polars as pl
import pandas as pd
df = pd.read_csv("sample.csv")
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  100 non-null    int64
#  1   Unnamed: 0    100 non-null    int64
#  2   WritingDate   100 non-null    object
#  3   Title         100 non-null    object
#  4   Conclusion    100 non-null    object
#  5   OrgNameDisc   100 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB
# None
#    Unnamed: 0.1  Unnamed: 0 WritingDate  \
# 0             0           0  2025-05-12
# 1             1           1  2025-05-11
# 2             2           2  2025-05-09
# 3             3           3  2025-05-08
# 4             4           4  2025-05-09
#
#                                         Title  \
# 0           汉朔科技(301275)：电子价签行业领跑者 助力泛零售数字化升级
# 1             科大智能(300222)：战略聚焦数字能源 拓展智能机器人应用
# 2  海晨股份(300873)：业内稀缺跨领域物流方案提供商 AMHS业务构筑第二成长曲线
# ...

# %%
call_llm('hello')
# Out:
# 'Hello! How can I assist you today?'

# %%
prompt='classify the text is generated by human/ai/unsure. only give the result. do not say anything else.\n\n'
prompt_2='classify the text is generated by human/ai/unsure. only give the result. Then give a classification of each text. do not say anything else.\n\n'
prompt_3='Then classify each sentence by Highly-Likely AI generated, Highly-Likely Human Rated, and Unsure classes. do not say anything else.\n\n'2
result_list=[]
for i in range(100):
    
    api_response=call_llm(prompt+df['Conclusion'][i])
    result_list.append(api_response)
    print(i,api_response)
# Out:
# 0 human
# 1 ai
# 2 unsure
# 3 ai
# 4 human
# 5 AI
# 6 AI
# 7 human
# 8 ai
# 9 ai
# 10 ai
# 11 unsure
# 12 human
# 13 human
# 14 ai
# 15 AI
# 16 AI
# 17 human
# 18 human
# 19 ai
# 20 ai
# 21 ai
# 22 unsure
# 23 human
# 24 AI
# 25 ai
# 26 ai
# 27 unsure
# 28 unsure
# 29 ai
# 30 ai
# 31 ai
# 32 unsure
# 33 ai
# 34 ai
# 35 unsure
# 36 human
# 37 ai
# 38 unsure
# 39 human
# 40 AI
# 41 ai
# 42 human
# 43 ai
# 44 ai
# 45 unsure
# 46 ai
# 47 ai
# 48 human
# 49 unsure
# 50 unsure
# 51 ai
# 52 unsure
# 53 AI
# 54 ai
# 55 unsure
# 56 AI
# 57 ai
# 58 human
# 59 ai
# 60 ai
# 61 human
# 62 human
# 63 unsure
# 64 human
# 65 ai
# 66 human
# 67 human
# 68 unsure
# 69 human
# 70 ai
# 71 human
# 72 ai
# 73 human
# 74 unsure
# 75 human
# 76 ai
# 77 human
# 78 unsure
# 79 ai
# 80 human
# 81 AI
# 82 human
# 83 ai
# 84 human
# 85 ai
# 86 unsure
# 87 ai
# 88 ai
# 89 ai
# 90 human
# 91 unsure
# 92 ai
# 93 unsure
# 94 human
# 95 human
# 96 unsure
# 97 human
# 98 ai
# 99 unsure

# %%
pd.DataFrame(result_list).to_csv('result_grok.csv')
